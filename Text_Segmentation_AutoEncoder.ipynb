# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# Load the data to workspace

# %%
# !cp -r "/content/drive/My Drive/dl/x1.zip" /content/
# !cp -r "/content/drive/My Drive/dl/x2.zip" /content/
# !cp -r "/content/drive/My Drive/dl/x3.zip" /content/
# !cp -r "/content/drive/My Drive/dl/x4.zip" /content/
# !cp "/content/drive/My Drive/dl/y.zip" /content/
# !unzip y.zip
# !unzip x1.zip
# !unzip x2.zip
# !unzip x3.zip
# !unzip x4.zip
# !mkdir x
# !cp -a "/content/x1/." /content/x/
# !cp -a "/content/x2/." /content/x/
# !cp -a "/content/x3/." /content/x/
# !cp -a "/content/x4/." /content/x/
# !rm y.zip
# !rm x1.zip
# !rm x2.zip
# !rm x3.zip
# !rm x4.zip
# !rm -r x1
# !rm -r x2
# !rm -r x3
# !rm -r x4
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: y/080 (2).bmp
#   inflating: y/080.bmp
#   inflating: y/080116-0053.bmp
#   inflating: y/080116-0055.bmp
#   inflating: y/080116-0056.bmp
#   inflating: y/080116-0057.bmp
#   inflating: y/080116-0058.bmp
#   inflating: y/080116-0059.bmp
#   inflating: y/080116-0060.bmp
#   inflating: y/080116-0063.bmp
#   inflating: y/080116-0064.bmp
#   inflating: y/080116-0065.bmp
#   inflating: y/080116-0066.bmp
#   inflating: y/080116-0072.bmp
#   inflating: y/080116-0079.bmp
#   inflating: y/080116-0084.bmp
#   inflating: y/080116-0089.bmp
#   inflating: y/080118-0007.bmp
#   inflating: y/080118-0011.bmp
#   inflating: y/080118-0014.bmp
#   inflating: y/080118-0017.bmp
#   inflating: y/080118-0018.bmp
#   inflating: y/080119-0001.bmp
#   inflating: y/080119-0003.bmp
#   inflating: y/080119-0004.bmp
#   inflating: y/080119-0005.bmp
#   inflating: y/080119-0006.bmp
#   inflating: y/080119-0007.bmp
#   inflating: y/080119-0008.bmp
#   inflating: y/080119-0009.bmp
#   inflating: y/080119-0011.bmp
#   inflating: y/080119-0012.bmp
#   inflating: y/080119-0013.bmp
#   inflating: y/080119-0014.bmp
#   inflating: y/080119-0015.bmp
#   inflating: y/080119-0016.bmp
#   inflating: y/080119-0017.bmp
#   inflating: y/080119-0018.bmp
#   inflating: y/080119-0020.bmp
#   inflating: y/080119-0026.bmp
#   inflating: y/080119-0027.bmp
#   inflating: y/080119-0029.bmp
#   inflating: y/080119-0030.bmp
#   inflating: y/080119-0031.bmp
#   inflating: y/080119-0032.bmp
#   inflating: y/080119-0033.bmp
#   inflating: y/080119-0035.bmp
#   inflating: y/080119-0036.bmp
#   inflating: y/080119-0037.bmp
#   inflating: y/080119-0038.bmp
#   inflating: y/080120-0001.bmp
#   inflating: y/081.bmp
#   inflating: y/082.bmp
#   inflating: y/083.bmp
#   inflating: y/085 (2).bmp
#   inflating: y/085.bmp
#   inflating: y/086 (2).bmp
#   inflating: y/086.bmp
#   inflating: y/087.bmp
#   inflating: y/088.bmp
#   inflating: y/089 (2).bmp
#   inflating: y/089.bmp
#   inflating: y/090 (2).bmp
#   inflating: y/090.bmp
#   inflating: y/091.bmp
#   inflating: y/092.bmp
#   inflating: y/093.bmp
#   inflating: y/094 (2).bmp
#   inflating: y/094.bmp
#   inflating: y/095.bmp
#   inflating: y/096 (2).bmp
#   inflating: y/096.bmp
#   inflating: y/097 (2).bmp
#   inflating: y/097.bmp
#   inflating: y/098.bmp
#   inflating: y/099.bmp
#   inflating: y/1 (2).bmp
#   inflating: y/1 (3).bmp
#   inflating: y/1.bmp
#   inflating: y/10.bmp
#   inflating: y/100 (2).bmp
#   inflating: y/100.bmp
#   inflating: y/101.bmp
#   inflating: y/102.bmp
#   inflating: y/103.bmp
#   inflating: y/104 (2).bmp
#   inflating: y/104.bmp
#   inflating: y/105 (2).bmp
#   inflating: y/105.bmp
#   inflating: y/106 (2).bmp
#   inflating: y/106.bmp
#   inflating: y/107.bmp
#   inflating: y/108.bmp
#   inflating: y/109 (2).bmp
#   inflating: y/109.bmp
#   inflating: y/11.bmp
#   inflating: y/110 (2).bmp
#   inflating: y/110.bmp
#   inflating: y/111 (2).bmp
#   inflating: y/111.bmp
#   inflating: y/112.bmp
#   inflating: y/113 (2).bmp
#   inflating: y/113.bmp
#   inflating: y/114.bmp
#   inflating: y/115 (2).bmp
#   inflating: y/115.bmp
#   inflating: y/116.bmp
#   inflating: y/117 (2).bmp
#   inflating: y/117.bmp
#   inflating: y/118.bmp
#   inflating: y/119.bmp
#   inflating: y/12.bmp
#   inflating: y/120.bmp
#   inflating: y/121.bmp
#   inflating: y/122.bmp
#   inflating: y/123.bmp
#   inflating: y/124.bmp
#   inflating: y/125.bmp
#   inflating: y/126.bmp
#   inflating: y/127.bmp
#   inflating: y/128.bmp
#   inflating: y/129.bmp
#   inflating: y/130.bmp
#   inflating: y/131.bmp
#   inflating: y/132.bmp
#   inflating: y/133.bmp
#   inflating: y/134.bmp
#   inflating: y/135.bmp
#   inflating: y/136.bmp
#   inflating: y/137.bmp
#   inflating: y/138.bmp
#   inflating: y/139.bmp
#   inflating: y/14.bmp
#   inflating: y/140.bmp
#   inflating: y/141.bmp
#   inflating: y/142.bmp
#   inflating: y/144.bmp
#   inflating: y/145.bmp
#   inflating: y/146.bmp
#   inflating: y/15.bmp
#   inflating: y/16.bmp
#   inflating: y/17.bmp
#   inflating: y/18.bmp
#   inflating: y/19.bmp
#   inflating: y/2 (2).bmp
#   inflating: y/2.bmp
#   inflating: y/20.bmp
#   inflating: y/2007-12-08-day-012.bmp
#   inflating: y/2007-12-08-day-015.bmp
#   inflating: y/2007-12-08-day-044.bmp
#   inflating: y/2007-12-08-day-045.bmp
#   inflating: y/2007-12-08-day-047.bmp
#   inflating: y/2007-12-08-day-050.bmp
#   inflating: y/2007-12-08-day-056.bmp
#   inflating: y/2007-12-08-day-057.bmp
#   inflating: y/2007-12-08-day-065.bmp
#   inflating: y/2007-12-08-day-067.bmp
#   inflating: y/2007-12-08-day-087.bmp
#   inflating: y/2007-12-08-day-091.bmp
#   inflating: y/2007-12-08-day-092.bmp
#   inflating: y/2007-12-08-day-094.bmp
#   inflating: y/2007-12-08-day-098.bmp
#   inflating: y/2007-12-08-day-099.bmp
#   inflating: y/2007-12-08-day-101.bmp
#   inflating: y/2007-12-08-day-103.bmp
#   inflating: y/2007-12-08-day-106.bmp
#   inflating: y/2007-12-08-day-108.bmp
#   inflating: y/2007-12-08-day-109.bmp
#   inflating: y/2007-12-08-day-111.bmp
#   inflating: y/2007-12-08-day-112.bmp
#   inflating: y/2007-12-08-day-113.bmp
#   inflating: y/2007-12-08-day-114.bmp
#   inflating: y/2007-12-08-day-117.bmp
#   inflating: y/2007-12-08-day-118.bmp
#   inflating: y/2007-12-08-day-122.bmp
#   inflating: y/2007-12-08-day-125.bmp
#   inflating: y/2007-12-08-day-129.bmp
#   inflating: y/2007-12-08-day-130.bmp
#   inflating: y/2007-12-08-day-132.bmp
#   inflating: y/2007-12-08-day-137.bmp
#   inflating: y/2007-12-08-day-139.bmp
#   inflating: y/2007-12-09-day-exterior-004.bmp
#   inflating: y/2007-12-09-day-exterior-005.bmp
#   inflating: y/2007-12-09-day-exterior-006.bmp
#   inflating: y/2007-12-09-day-exterior-007.bmp
#   inflating: y/2007-12-09-day-exterior-008.bmp
#   inflating: y/2007-12-09-day-exterior-009.bmp
#   inflating: y/2007-12-09-day-exterior-012.bmp
#   inflating: y/2007-12-09-day-exterior-016.bmp
#   inflating: y/2007-12-09-day-exterior-023.bmp
#   inflating: y/2007-12-09-day-exterior-025.bmp
#   inflating: y/2007-12-09-day-exterior-026.bmp
#   inflating: y/2007-12-09-day-exterior-028.bmp
#   inflating: y/2007-12-09-day-exterior-031.bmp
#   inflating: y/2007-12-09-day-exterior-032.bmp
#   inflating: y/2007-12-09-day-exterior-033.bmp
#   inflating: y/2007-12-09-day-exterior-035.bmp
#   inflating: y/2007-12-09-day-exterior-036.bmp
#   inflating: y/2007-12-09-day-exterior-037.bmp
#   inflating: y/2007-12-09-day-exterior-040.bmp
#   inflating: y/2007-12-09-day-exterior-044.bmp
#   inflating: y/2007-12-09-day-exterior-047.bmp
#   inflating: y/2007-12-09-day-exterior-051.bmp
#   inflating: y/2007-12-09-day-exterior-055.bmp
#   inflating: y/2007-12-09-day-exterior-056.bmp
#   inflating: y/2007-12-09-day-exterior-062.bmp
#   inflating: y/2007-12-09-day-exterior-063.bmp
#   inflating: y/2007-12-09-day-exterior-068.bmp
#   inflating: y/2007-12-09-day-exterior-078.bmp
#   inflating: y/2007-12-09-day-exterior-083.bmp
#   inflating: y/2007-12-09-day-exterior-084.bmp
#   inflating: y/2007-12-09-day-exterior-086.bmp
#   inflating: y/21.bmp
#   inflating: y/22.bmp
#   inflating: y/23.bmp
#   inflating: y/24.bmp
#   inflating: y/25.bmp
#   inflating: y/26.bmp
#   inflating: y/27.bmp
#   inflating: y/3 (2).bmp
#   inflating: y/3.bmp
#   inflating: y/30.bmp
#   inflating: y/306.bmp
#   inflating: y/307.bmp
#   inflating: y/308.bmp
#   inflating: y/31.bmp
#   inflating: y/32.bmp
#   inflating: y/33.bmp
#   inflating: y/34.bmp
#   inflating: y/35.bmp
#   inflating: y/36.bmp
#   inflating: y/38.bmp
#   inflating: y/39.bmp
#   inflating: y/4.bmp
#   inflating: y/40.bmp
#   inflating: y/41.bmp
#   inflating: y/42.bmp
#   inflating: y/43.bmp
#   inflating: y/44.bmp
#   inflating: y/45 (2).bmp
#   inflating: y/45.bmp
#   inflating: y/46.bmp
#   inflating: y/47.bmp
#   inflating: y/48.bmp
#   inflating: y/49.bmp
#   inflating: y/5 (2).bmp
#   inflating: y/5.bmp
#   inflating: y/50.bmp
#   inflating: y/51.bmp
#   inflating: y/53.bmp
#   inflating: y/54.bmp
#   inflating: y/55.bmp
#   inflating: y/56.bmp
#   inflating: y/57.bmp
#   inflating: y/58.bmp
#   inflating: y/59.bmp
#   inflating: y/6.bmp
#   inflating: y/7.bmp
#   inflating: y/8.bmp
#   inflating: y/9.bmp
#   inflating: y/91.bmp
#   inflating: y/99.bmp
#   inflating: y/DSC02240.bmp
#   inflating: y/DSC02242.bmp
#   inflating: y/DSC02243.bmp
#   inflating: y/DSC02244.bmp
#   inflating: y/DSC02298.bmp
#   inflating: y/DSC02299.bmp
#   inflating: y/DSC02300.bmp
#   inflating: y/DSC02302.bmp
#   inflating: y/DSC02304.bmp
#   inflating: y/DSC02305.bmp
#   inflating: y/DSC02306.bmp
#   inflating: y/DSC02307.bmp
#   inflating: y/DSC02308.bmp
#   inflating: y/DSC02309.bmp
#   inflating: y/DSC02310.bmp
#   inflating: y/DSC02311.bmp
#   inflating: y/DSC02312.bmp
#   inflating: y/DSC02313.bmp
#   inflating: y/DSC02314.bmp
#   inflating: y/DSC02317.bmp
#   inflating: y/DSC02318.bmp
#   inflating: y/DSC02319.bmp
#   inflating: y/DSC02320.bmp
#   inflating: y/DSC02321.bmp
#   inflating: y/DSC02322.bmp
#   inflating: y/DSC02323.bmp
#   inflating: y/DSC02325.bmp
#   inflating: y/DSC02326.bmp
#   inflating: y/DSC02327.bmp
#   inflating: y/DSC02343.bmp
#   inflating: y/DSC02344.bmp
#   inflating: y/DSC02345.bmp
#   inflating: y/DSC02349.bmp
#   inflating: y/DSC02350.bmp
#   inflating: y/DSC02352.bmp
#   inflating: y/DSC02353.bmp
#   inflating: y/DSC02354.bmp
#   inflating: y/DSC02355.bmp
#   inflating: y/DSC02356.bmp
#   inflating: y/DSC02357.bmp
#   inflating: y/DSC02358.bmp
#   inflating: y/DSC02359.bmp
#   inflating: y/DSC02360.bmp
#   inflating: y/DSC02361.bmp
#   inflating: y/DSC02364.bmp
#   inflating: y/DSC02365.bmp
#   inflating: y/DSC02366.bmp
#   inflating: y/DSC02368.bmp
#   inflating: y/DSC02371.bmp
#   inflating: y/DSC02372.bmp
#   inflating: y/DSC02373.bmp
#   inflating: y/DSC02374.bmp
#   inflating: y/DSC02376.bmp
#   inflating: y/DSC02377.bmp
#   inflating: y/DSC02378.bmp
#   inflating: y/DSC02379.bmp
#   inflating: y/DSC02380.bmp
#   inflating: y/DSC02381.bmp
#   inflating: y/DSC02382.bmp
#   inflating: y/DSC02383.bmp
#   inflating: y/DSC02384.bmp
#   inflating: y/DSC02385.bmp
#   inflating: y/DSC02386.bmp
#   inflating: y/DSC02387.bmp
#   inflating: y/DSC02388.bmp
#   inflating: y/DSC02389.bmp
#   inflating: y/DSC02390.bmp
#   inflating: y/DSC02391.bmp
#   inflating: y/DSC02393.bmp
#   inflating: y/DSC02394.bmp
#   inflating: y/DSC02395.bmp
#   inflating: y/DSC02396.bmp
#   inflating: y/DSC02397.bmp
#   inflating: y/DSC02398.bmp
#   inflating: y/DSC02400.bmp
#   inflating: y/DSC02405.bmp
#   inflating: y/DSC02406.bmp
#   inflating: y/DSC02407.bmp
#   inflating: y/DSC02408.bmp
#   inflating: y/DSC02409.bmp
#   inflating: y/DSC02410.bmp
#   inflating: y/DSC02411.bmp
#   inflating: y/DSC02412.bmp
#   inflating: y/DSC02413.bmp
#   inflating: y/DSC02414.bmp
#   inflating: y/DSC02415.bmp
#   inflating: y/DSC02416.bmp
#   inflating: y/DSC02417.bmp
#   inflating: y/DSC02418.bmp
#   inflating: y/DSC02419.bmp
#   inflating: y/DSC02420.bmp
#   inflating: y/DSC02421.bmp
#   inflating: y/DSC02422.bmp
#   inflating: y/DSC02423.bmp
#   inflating: y/DSC02424.bmp
#   inflating: y/DSC02425.bmp
#   inflating: y/DSC02426.bmp
#   inflating: y/DSC02427.bmp
#   inflating: y/DSC02429.bmp
#   inflating: y/DSC02430.bmp
#   inflating: y/DSC02432.bmp
#   inflating: y/DSC02433.bmp
#   inflating: y/DSC02434.bmp
#   inflating: y/DSC02435.bmp
#   inflating: y/DSC02436.bmp
#   inflating: y/DSC02439.bmp
#   inflating: y/DSC02441.bmp
#   inflating: y/DSC02442.bmp
#   inflating: y/DSC02445.bmp
#   inflating: y/DSC02446.bmp
#   inflating: y/DSC02447.bmp
#   inflating: y/DSC02448.bmp
#   inflating: y/DSC02449.bmp
#   inflating: y/DSC02450.bmp
#   inflating: y/DSC02451.bmp
#   inflating: y/DSC02452.bmp
#   inflating: y/DSC02453.bmp
#   inflating: y/DSC02460.bmp
#   inflating: y/DSC02461.bmp
#   inflating: y/DSC02463.bmp
#   inflating: y/DSC02464.bmp
#   inflating: y/DSC02465.bmp
#   inflating: y/DSC02466.bmp
#   inflating: y/DSC02467.bmp
#   inflating: y/DSC02468.bmp
#   inflating: y/DSC02470.bmp
#   inflating: y/DSC02471.bmp
#   inflating: y/DSC02472.bmp
#   inflating: y/DSC02474.bmp
#   inflating: y/DSC02475.bmp
#   inflating: y/DSC02476.bmp
#   inflating: y/DSC02477.bmp
#   inflating: y/DSC02478.bmp
#   inflating: y/DSC02479.bmp
#   inflating: y/DSC02480.bmp
#   inflating: y/DSC02481.bmp
#   inflating: y/DSC02482.bmp
#   inflating: y/DSC02483.bmp
#   inflating: y/DSC02485.bmp
#   inflating: y/DSC02486.bmp
#   inflating: y/DSC02487.bmp
#   inflating: y/DSC02488.bmp
#   inflating: y/DSC02489.bmp
#   inflating: y/DSC02490.bmp
#   inflating: y/DSC02491.bmp
#   inflating: y/DSC02492.bmp
#   inflating: y/DSC02493.bmp
#   inflating: y/DSC02494.bmp
#   inflating: y/DSC02495.bmp
#   inflating: y/DSC02496.bmp
#   inflating: y/DSC02497.bmp
#   inflating: y/DSC02498.bmp
#   inflating: y/DSC02499.bmp
#   inflating: y/DSC02500.bmp
#   inflating: y/DSC02501.bmp
#   inflating: y/DSC02502.bmp
#   inflating: y/DSC02503.bmp
#   inflating: y/DSC02504.bmp
#   inflating: y/DSC02505.bmp
#   inflating: y/DSC02506.bmp
#   inflating: y/DSC02507.bmp
#   inflating: y/DSC02508.bmp
#   inflating: y/DSC02511.bmp
#   inflating: y/DSC02512.bmp
#   inflating: y/DSC02513.bmp
#   inflating: y/DSC02514.bmp
#   inflating: y/DSC02515.bmp
#   inflating: y/DSC02518.bmp
#   inflating: y/DSC02519.bmp
#   inflating: y/DSC02520.bmp
#   inflating: y/DSC02521.bmp
#   inflating: y/DSC02522.bmp
#   inflating: y/DSC02523.bmp
#   inflating: y/DSC02524.bmp
#   inflating: y/DSC02525.bmp
#   inflating: y/DSC02527.bmp
#   inflating: y/DSC02528.bmp
#   inflating: y/DSC02529.bmp
#   inflating: y/DSC02530.bmp
#   inflating: y/DSC02531.bmp
#   inflating: y/DSC02532.bmp
#   inflating: y/DSC02533.bmp
#   inflating: y/DSC02536.bmp
#   inflating: y/DSC02537.bmp
#   inflating: y/DSC02538.bmp
#   inflating: y/DSC02539.bmp
#   inflating: y/DSC02540.bmp
#   inflating: y/DSC02541.bmp
#   inflating: y/DSC02542.bmp
#   inflating: y/DSC02543.bmp
#   inflating: y/DSC02544.bmp
#   inflating: y/DSC02545.bmp
#   inflating: y/DSC02546.bmp
#   inflating: y/DSC02550.bmp
#   inflating: y/DSC02551.bmp
#   inflating: y/DSC02552.bmp
#   inflating: y/DSC02553.bmp
#   inflating: y/DSC02554.bmp
#   inflating: y/DSC02555.bmp
#   inflating: y/DSC02556.bmp
#   inflating: y/DSC02557.bmp
#   inflating: y/DSC02558.bmp
#   inflating: y/DSC02559.bmp
#   inflating: y/DSC02560.bmp
#   inflating: y/DSC02561.bmp
#   inflating: y/DSC02562.bmp
#   inflating: y/DSC02565.bmp
#   inflating: y/DSC02567 (2).bmp
#   inflating: y/DSC02567.bmp
#   inflating: y/DSC02568 (2).bmp
#   inflating: y/DSC02568.bmp
#   inflating: y/DSC02569.bmp
#   inflating: y/DSC02570.bmp
#   inflating: y/DSC02571.bmp
#   inflating: y/DSC02572.bmp
#   inflating: y/DSC02573.bmp
#   inflating: y/DSC02574.bmp
#   inflating: y/DSC02575.bmp
#   inflating: y/DSC02579.bmp
#   inflating: y/DSC02581.bmp
#   inflating: y/DSC02582.bmp
#   inflating: y/DSC02584.bmp
#   inflating: y/DSC02585.bmp
#   inflating: y/DSC02586.bmp
#   inflating: y/DSC02587.bmp
#   inflating: y/DSC02588.bmp
#   inflating: y/DSC02590.bmp
#   inflating: y/DSC02593.bmp
#   inflating: y/DSC02594.bmp
#   inflating: y/DSC02595.bmp
#   inflating: y/DSC02596.bmp
#   inflating: y/DSC02597.bmp
#   inflating: y/DSC02598 (2).bmp
#   inflating: y/DSC02598.bmp
#   inflating: y/DSC02599.bmp
#   inflating: y/DSC02600.bmp
#   inflating: y/DSC02602.bmp
#   inflating: y/DSC02604.bmp
#   inflating: y/DSC02605.bmp
#   inflating: y/DSC02606.bmp
#   inflating: y/DSC02608.bmp
#   inflating: y/DSC02609 (2).bmp
#   inflating: y/DSC02609.bmp
#   inflating: y/DSC02610.bmp
#   inflating: y/DSC02611.bmp
#   inflating: y/DSC02612.bmp
#   inflating: y/DSC02613.bmp
#   inflating: y/DSC02614.bmp
#   inflating: y/DSC02615.bmp
#   inflating: y/DSC02618.bmp
#   inflating: y/DSC02619.bmp
#   inflating: y/DSC02620.bmp
#   inflating: y/DSC02621.bmp
#   inflating: y/DSC02622.bmp
#   inflating: y/DSC02623.bmp
#   inflating: y/DSC02624 (2).bmp
#   inflating: y/DSC02624.bmp
#   inflating: y/DSC02626.bmp
#   inflating: y/DSC02629.bmp
#   inflating: y/DSC02631.bmp
#   inflating: y/DSC02633.bmp
#   inflating: y/DSC02635.bmp
#   inflating: y/DSC02638.bmp
#   inflating: y/DSC02639.bmp
#   inflating: y/DSC02640.bmp
#   inflating: y/DSC02641.bmp
#   inflating: y/DSC02642.bmp
#   inflating: y/DSC02643.bmp
#   inflating: y/DSC02644.bmp
#   inflating: y/DSC02645.bmp
#   inflating: y/DSC02646.bmp
#   inflating: y/DSC02647.bmp
#   inflating: y/DSC02648.bmp
#   inflating: y/DSC02649.bmp
#   inflating: y/DSC02651.bmp
#   inflating: y/DSC02652.bmp
#   inflating: y/DSC02653.bmp
#   inflating: y/DSC02654.bmp
#   inflating: y/DSC02656.bmp
#   inflating: y/DSC02658.bmp
#   inflating: y/DSC02659.bmp
#   inflating: y/DSC02660.bmp
#   inflating: y/DSC02662.bmp
#   inflating: y/DSC02663.bmp
#   inflating: y/DSC02664.bmp
#   inflating: y/DSC02665.bmp
#   inflating: y/DSC02667.bmp
#   inflating: y/DSC02668.bmp
#   inflating: y/DSC02670.bmp
#   inflating: y/DSC02672.bmp
#   inflating: y/DSC02673.bmp
#   inflating: y/DSC02674.bmp
#   inflating: y/DSC02675.bmp
#   inflating: y/DSC02676.bmp
#   inflating: y/DSC02678.bmp
#   inflating: y/DSC02686.bmp
#   inflating: y/DSC02687.bmp
#   inflating: y/DSC02688.bmp
#   inflating: y/DSC02690.bmp
#   inflating: y/DSC02693.bmp
#   inflating: y/DSC02696.bmp
#   inflating: y/DSC02697.bmp
#   inflating: y/DSC02698.bmp
#   inflating: y/DSC02699.bmp
#   inflating: y/DSC02700.bmp
#   inflating: y/DSC02701.bmp
#   inflating: y/DSC02702.bmp
#   inflating: y/DSC02704.bmp
#   inflating: y/DSC02705.bmp
#   inflating: y/DSC02706.bmp
#   inflating: y/DSC02707.bmp
#   inflating: y/DSC02708.bmp
#   inflating: y/DSC02710.bmp
#   inflating: y/DSC02711.bmp
#   inflating: y/DSC02712.bmp
#   inflating: y/DSC02713.bmp
#   inflating: y/DSC02714.bmp
#   inflating: y/DSC02715.bmp
#   inflating: y/DSC02716.bmp
#   inflating: y/DSC02717.bmp
#   inflating: y/DSC02718.bmp
#   inflating: y/DSC02719.bmp
#   inflating: y/DSC02720.bmp
#   inflating: y/DSC02721.bmp
#   inflating: y/DSC02722.bmp
#   inflating: y/DSC02723.bmp
#   inflating: y/DSC02724.bmp
#   inflating: y/DSC02725.bmp
#   inflating: y/DSC02726.bmp
#   inflating: y/DSC02727.bmp
#   inflating: y/DSC02728.bmp
#   inflating: y/DSC02729.bmp
#   inflating: y/DSC02730.bmp
#   inflating: y/DSC02731.bmp
#   inflating: y/DSC02732.bmp
#   inflating: y/DSC02733.bmp
#   inflating: y/DSC02734.bmp
#   inflating: y/DSC02735.bmp
#   inflating: y/DSC02736.bmp
#   inflating: y/DSC02737.bmp
#   inflating: y/DSC02738.bmp
#   inflating: y/DSC02739.bmp
#   inflating: y/DSC02740.bmp
#   inflating: y/DSC02741.bmp
#   inflating: y/DSC02742.bmp
#   inflating: y/DSC02743.bmp
#   inflating: y/DSC02744.bmp
#   inflating: y/DSC02745.bmp
#   inflating: y/DSC02746.bmp
#   inflating: y/DSC02747.bmp
#   inflating: y/DSC02748.bmp
#   inflating: y/DSC02749.bmp
#   inflating: y/DSC02750.bmp
#   inflating: y/DSC02751.bmp
#   inflating: y/DSC02752.bmp
#   inflating: y/DSC02755.bmp
#   inflating: y/DSC02756.bmp
#   inflating: y/DSC02757.bmp
#   inflating: y/DSC02758.bmp
#   inflating: y/DSC02759.bmp
#   inflating: y/DSC02760.bmp
#   inflating: y/DSC02761.bmp
#   inflating: y/DSC02763.bmp
#   inflating: y/DSC02765.bmp
#   inflating: y/DSC02766.bmp
#   inflating: y/DSC02767.bmp
#   inflating: y/DSC02768.bmp
#   inflating: y/DSC02769.bmp
#   inflating: y/DSC02770.bmp
#   inflating: y/DSC02771.bmp
#   inflating: y/DSC02772.bmp
#   inflating: y/DSC02774.bmp
#   inflating: y/DSC02775.bmp
#   inflating: y/DSC02776.bmp
#   inflating: y/DSC02777.bmp
#   inflating: y/DSC02778.bmp
#   inflating: y/DSC02780.bmp
#   inflating: y/DSC02782.bmp
#   inflating: y/DSC02785.bmp
#   inflating: y/DSC02787.bmp
#   inflating: y/DSC02788.bmp
#   inflating: y/DSC02789.bmp
#   inflating: y/DSC02791.bmp
#   inflating: y/DSC02793.bmp
#   inflating: y/DSC02794.bmp
#   inflating: y/DSC02795.bmp
#   inflating: y/DSC02796.bmp
#   inflating: y/DSC02797.bmp
#   inflating: y/DSC02799.bmp
#   inflating: y/DSC02800.bmp
#   inflating: y/DSC02801.bmp
#   inflating: y/DSC02802.bmp
#   inflating: y/DSC02803.bmp
#   inflating: y/DSC02804.bmp
#   inflating: y/DSC02806.bmp
#   inflating: y/DSC02807.bmp
#   inflating: y/DSC02811.bmp
#   inflating: y/DSC02812.bmp
#   inflating: y/DSC02813.bmp
#   inflating: y/DSC02814.bmp
#   inflating: y/DSC02815.bmp
#   inflating: y/DSC02818.bmp
#   inflating: y/DSC02819.bmp
#   inflating: y/DSC02820.bmp
#   inflating: y/DSC02821.bmp
#   inflating: y/DSC02822.bmp
#   inflating: y/DSC02823.bmp
#   inflating: y/DSC02824.bmp
#   inflating: y/DSC02826.bmp
#   inflating: y/DSC02827.bmp
#   inflating: y/DSC02828.bmp
#   inflating: y/DSC02829.bmp
#   inflating: y/DSC02830.bmp
#   inflating: y/DSC02831.bmp
#   inflating: y/DSC02832.bmp
#   inflating: y/DSC02833.bmp
#   inflating: y/DSC02834.bmp
#   inflating: y/DSC02835.bmp
#   inflating: y/DSC02836.bmp
#   inflating: y/DSC02838.bmp
#   inflating: y/DSC02839.bmp
#   inflating: y/DSC02840.bmp
#   inflating: y/DSC02842.bmp
#   inflating: y/DSC02850.bmp
#   inflating: y/DSC02852.bmp
#   inflating: y/DSC02853.bmp
#   inflating: y/DSC02854.bmp
#   inflating: y/DSC02857.bmp
#   inflating: y/DSC02858.bmp
#   inflating: y/DSC02859.bmp
#   inflating: y/DSC02860.bmp
#   inflating: y/DSC02861.bmp
#   inflating: y/DSC02862.bmp
#   inflating: y/DSC02864.bmp
#   inflating: y/DSC02865.bmp
#   inflating: y/DSC02866.bmp
#   inflating: y/DSC02867.bmp
#   inflating: y/DSC02868.bmp
#   inflating: y/DSC02869.bmp
#   inflating: y/DSC02870.bmp
#   inflating: y/DSC02871.bmp
#   inflating: y/DSC02872.bmp
#   inflating: y/DSC02873.bmp
#   inflating: y/DSC02874.bmp
#   inflating: y/DSC02875.bmp
#   inflating: y/DSC02876.bmp
#   inflating: y/DSC02877.bmp
#   inflating: y/DSC02878.bmp
#   inflating: y/DSC02879.bmp
#   inflating: y/DSC02880.bmp
#   inflating: y/DSC02881.bmp
#   inflating: y/DSC02884.bmp
#   inflating: y/DSC02885.bmp
#   inflating: y/DSC02886.bmp
#   inflating: y/DSC02887.bmp
#   inflating: y/DSC02888.bmp
#   inflating: y/DSC02889.bmp
#   inflating: y/DSC02890.bmp
#   inflating: y/DSC02891.bmp
#   inflating: y/DSC02893.bmp
#   inflating: y/DSC02894.bmp
#   inflating: y/DSC02895.bmp
#   inflating: y/DSC02896.bmp
#   inflating: y/DSC02897.bmp
#   inflating: y/DSC02899.bmp
#   inflating: y/DSC02900.bmp
#   inflating: y/DSC02901.bmp
#   inflating: y/DSC02902.bmp
#   inflating: y/DSC02903.bmp
#   inflating: y/DSC02904.bmp
#   inflating: y/DSC02907.bmp
#   inflating: y/DSC02908.bmp
#   inflating: y/DSC02909.bmp
#   inflating: y/DSC02910.bmp
#   inflating: y/DSC02911.bmp
#   inflating: x4/P1010164.JPG
#   inflating: x4/P1010170.JPG
#   inflating: x4/P1010171.JPG
#   inflating: x4/P1010172.JPG
#   inflating: x4/P1010178.JPG
#   inflating: x4/P1010181.JPG
#   inflating: x4/P1010189.JPG
#   inflating: x4/P1011112.JPG
#   inflating: x4/r.jpg
#   inflating: x4/s.jpg
# x4/sharp2╣°_039.jpg:  mismatching "local" filename (x4/sharp2тХг┬░_039.jpg),
#          continuing with "central" filename version
#   inflating: x4/sharp2╣°_039.jpg
#   inflating: x4/t.jpg
#   inflating: x4/u.jpg
#   inflating: x4/v.jpg
#   inflating: x4/x.jpg
#   inflating: x4/z.jpg

# %%
# !rm -r /content/*

# %% [markdown]
# Load libraries

# %%
import numpy as np
import math
from keras.layers import Flatten, Dense, Input, Conv2D, MaxPooling2D, Dropout, Add, BatchNormalization,Conv1D, advanced_activations, UpSampling2D,Reshape
from keras.optimizers import Adam
from keras.models import Model
from keras import losses
import cv2
import tqdm
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
import os
from keras.callbacks import ModelCheckpoint, EarlyStopping
from keras.optimizers import Adam, SGD
from google.colab.patches import cv2_imshow
from keras.utils.vis_utils import plot_model
import cv2 as cv

# %% [markdown]
# Load the data from colab workspace to runtime variables

# %%
train_img = []
ground_truth = []
file_list1 = np.sort(os.listdir('/content/x/'))
file_list2 = np.sort(os.listdir('/content/y/'))
for i in tqdm.tqdm(range(0, len(file_list1))):
    ground_truth.append(cv2.resize(cv2.imread('/content/y/' + file_list2[i], 0),(640,480)))
    train_img.append(cv2.resize(cv2.imread('/content/x/' + file_list1[i], 1),(640,480)))
# Out:
# 100%|██████████| 2480/2480 [00:31<00:00, 78.26it/s]

# %%
np.shape(ground_truth[0])
# Out:
# (480, 640, 3)

# %%
#cv2_imshow(ground_truth[30])
plt.imshow(train_img[30])

# %%
plt.imshow(ground_truth[30])

# %%
np.random.seed(0)
train_img = np.array(train_img)
ground_truth = np.array(ground_truth)
train_img = train_img.reshape((-1, 480,640, 3))
ground_truth = ground_truth.reshape((-1, 480, 640, 1))
train_x, val_x, train_y, val_y = train_test_split(train_img, ground_truth, test_size=0.2)
del train_img
del ground_truth

# %%
print(np.shape(train_x),np.shape(val_x))
# Out:
# (1984, 480, 640, 3) (496, 480, 640, 3)

# %%
input_img = Input(shape=(480, 640, 3)) #RGB Image
x = Conv2D(16, (3, 3), padding='same')(input_img)
x = advanced_activations.LeakyReLU()(x)
x = Conv2D(16, (3, 3), padding='same')(input_img)
x = advanced_activations.LeakyReLU()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(64, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(128, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = MaxPooling2D((2, 2), padding='same')(x)
x = Conv2D(256, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
encoded = MaxPooling2D((2, 2), padding='same')(x)

x = Conv2D(256, (3, 3), padding='same')(encoded)
x = advanced_activations.LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(128, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(64, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(32, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)
x = Conv2D(16, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = Conv2D(16, (3, 3), padding='same')(x)
x = advanced_activations.LeakyReLU()(x)
x = UpSampling2D((2, 2))(x)
decoded = Conv2D(1, (3, 3), padding='same', activation='linear')(x) #Grey Scale image

MindNet = Model(input_img, decoded)
adam = Adam(lr=0.0001, beta_1=0.9, beta_2=0.999)
opt = SGD(lr=0.001, momentum=0.9) 
MindNet.compile(optimizer=adam, loss='mean_squared_error')

# %%
MindNet.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 480, 640, 3)       0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 480, 640, 16)      448
# _________________________________________________________________
# leaky_re_lu_14 (LeakyReLU)   (None, 480, 640, 16)      0
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 240, 320, 16)      0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 240, 320, 32)      4640
# _________________________________________________________________
# leaky_re_lu_15 (LeakyReLU)   (None, 240, 320, 32)      0
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 120, 160, 32)      0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 120, 160, 64)      18496
# _________________________________________________________________
# leaky_re_lu_16 (LeakyReLU)   (None, 120, 160, 64)      0
# _________________________________________________________________
# max_pooling2d_8 (MaxPooling2 (None, 60, 80, 64)        0
# _________________________________________________________________
# conv2d_18 (Conv2D)           (None, 60, 80, 128)       73856
# _________________________________________________________________
# leaky_re_lu_17 (LeakyReLU)   (None, 60, 80, 128)       0
# _________________________________________________________________
# max_pooling2d_9 (MaxPooling2 (None, 30, 40, 128)       0
# _________________________________________________________________
# conv2d_19 (Conv2D)           (None, 30, 40, 256)       295168
# _________________________________________________________________
# leaky_re_lu_18 (LeakyReLU)   (None, 30, 40, 256)       0
# _________________________________________________________________
# max_pooling2d_10 (MaxPooling (None, 15, 20, 256)       0
# _________________________________________________________________
# conv2d_20 (Conv2D)           (None, 15, 20, 256)       590080
# _________________________________________________________________
# leaky_re_lu_19 (LeakyReLU)   (None, 15, 20, 256)       0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 30, 40, 256)       0
# _________________________________________________________________
# conv2d_21 (Conv2D)           (None, 30, 40, 128)       295040
# _________________________________________________________________
# leaky_re_lu_20 (LeakyReLU)   (None, 30, 40, 128)       0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 60, 80, 128)       0
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 60, 80, 64)        73792
# _________________________________________________________________
# leaky_re_lu_21 (LeakyReLU)   (None, 60, 80, 64)        0
# _________________________________________________________________
# up_sampling2d_8 (UpSampling2 (None, 120, 160, 64)      0
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 120, 160, 32)      18464
# _________________________________________________________________
# leaky_re_lu_22 (LeakyReLU)   (None, 120, 160, 32)      0
# _________________________________________________________________
# up_sampling2d_9 (UpSampling2 (None, 240, 320, 32)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 240, 320, 16)      4624
# _________________________________________________________________
# leaky_re_lu_23 (LeakyReLU)   (None, 240, 320, 16)      0
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 240, 320, 16)      2320
# _________________________________________________________________
# leaky_re_lu_24 (LeakyReLU)   (None, 240, 320, 16)      0
# _________________________________________________________________
# up_sampling2d_10 (UpSampling (None, 480, 640, 16)      0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 480, 640, 1)       145
# =================================================================
# Total params: 1,377,073
# Trainable params: 1,377,073
# Non-trainable params: 0
# _________________________________________________________________

# %%
plot_model(MindNet, to_file='model_plot.png', show_shapes=True, show_layer_names=True)

# %%
checkpointer = ModelCheckpoint(filepath='./weights.best.3.hdf5', 
                               verbose = 1, 
                               save_best_only = True) # verbose =1 is for printing the output
history=MindNet.fit(train_x, train_y,
                epochs=15,
                batch_size=8,
                shuffle=True,
                validation_data=(val_x, val_y),
                callbacks = [checkpointer])

# %%
# !cp "/content/drive/My Drive/dl/weights.best.1.hdf5" /content/
# !cp "/content/drive/My Drive/dl/weights.best.2.hdf5" /content/
# !cp "/content/drive/My Drive/dl/weights.best.3.hdf5" /content/

# %%
MindNet.load_weights("./weights.best.1.hdf5")

# %%
# !cp /content/weights.best.1.hdf5 "/content/drive/My Drive/dl/"
# !cp /content/weights.best.2.hdf5 "/content/drive/My Drive/dl/"
# !cp /content/weights.best.3.hdf5 "/content/drive/My Drive/dl/"

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %%
decoded_imgs = MindNet.predict(val_x)
x=28
n = 5
plt.figure(figsize=(40, 16))
for i in range(x,n+x):
    # display original
    ax = plt.subplot(3, n, i-x+1)
    plt.imshow(val_y[i+10].reshape(480,640))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)

    # display reconstruction
    
    ax = plt.subplot(3, n, i+n-x+1)
    plt.imshow(val_x[i+10].reshape(480,640,3))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    ax = plt.subplot(3, n, i + 2*n-x+1)
    plt.imshow(decoded_imgs[i+10].reshape(480,640))
    plt.gray()
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
plt.show()

# %%
# serialize model to JSON
model_json = MindNet.to_json()
with open("modelMindNet.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
MindNet.save_weights("modelMindNet.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %%
# load json and create model
json_file = open('modelMindNet.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
MindNet = model_from_json(loaded_model_json)

# %%
# load weights into new model
MindNet.load_weights("modelMindNet.h5")
print("Loaded model from disk")
